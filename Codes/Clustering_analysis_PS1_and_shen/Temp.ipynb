# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as pt

# %%
x = np.random.uniform(0,1,50)
y = np.random.uniform(0,1,50)

fig, ax = plt.subplots(figsize=(5,5))
ax.scatter(x,y)
#ax.scatter(x[0], y[0], c='red')
xf, yf = 0.5-x[0], 0.5-y[0]
ax.arrow(x[0], y[0], x[1]-x[0], y[1]-y[0], width=0.005, head_width=0.005)
ax.arrow(x[2], y[2], x[3]-x[2], y[3]-y[2], width=0.005, head_width=0.005)
ax.arrow(x[4], y[4], x[5]-x[4], y[5]-y[4], width=0.005, head_width=0.005)
rec = pt.Rectangle((0.4, 0.4), 0.2, 0.2, fill=False)
ax.set_axis_off()
#ax.add_patch(rec)
